# %%
/# Specify variables
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as s
from haven import haven_utils as hu
import matplotlib as mpl
mpl.rc('image', cmap='tab20c')


# please define the path to the experiments
savedir_base = "/mnt/home/fbranchaud/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_noise']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list, 
                      savedir_base=savedir_base, 
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}

df = rm.get_exp_list_df()

# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>,
#  <Figure size 1440x1080 with 1 Axes>,
#  <Figure size 1440x1080 with 1 Axes>]

# %%
# please define the path to the experiments
savedir_base = "/mnt/home/fbranchaud/synbols_ckpt"
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_shuffle']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations', 'shuffle_prop']
avg_across='seed'
legend_format = '{}, I={}, SP={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-4-02134a83e335> in <module>
#      42
#      43 # launch dashboard
# ---> 44 rm.get_plot(**kwargs)
#      45
#
# ~/miniconda3/envs/synbols/lib/python3.7/site-packages/haven/haven_results.py in get_plot(self, groupby_list, savedir_plots, filterby_list, **kwargs)
#     142             fig, ax = get_plot(exp_list=exp_list, savedir_base=self.savedir_base, filterby_list=filterby_list,
#     143                         verbose=self.verbose,
# --> 144                                **kwargs)
#     145             fig_list += [fig]
#     146
#
# ~/miniconda3/envs/synbols/lib/python3.7/site-packages/haven/haven_results.py in get_plot(exp_list, savedir_base, x_metric, y_metric, mode, filterby_list, title_list, legend_list, log_metric_list, figsize, avg_across, fig, axis, ylim, xlim, legend_fontsize, y_fontsize, x_fontsize, ytick_fontsize, xtick_fontsize, title_fontsize, legend_kwargs, map_exp_list, map_title_list, map_xlabel_list, map_ylabel_list, bar_agg, verbose, show_legend, legend_format, cmap)
#     979                     visited.add(sub_id)
#     980
# --> 981                     sub_score_list = hu.load_pkl(sub_score_list_fname)
#     982
#     983                     for score_dict in sub_score_list:
#
# ~/miniconda3/envs/synbols/lib/python3.7/site-packages/haven/haven_utils.py in load_pkl(fname)
#     192     """
#     193     with open(fname, "rb") as f:
# --> 194         return pickle.load(f)
#     195
#     196
#
# UnpicklingError: pickle data was truncated

# %%
# please define the path to the experiments
savedir_base = "/mnt/projects/bayesian-active-learning/synbols_ckpt"
from benchmarks.scripts.active_learning import EXP_GROUPS
exp_list = EXP_GROUPS['active_char_betabald']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None
# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='test_loss'
x_metric='num_samples'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['query_size']
legend_list=['heuristic', 'iterations']
avg_across='seed'
legend_format = '{}, I={}'

# get experiments
rm = hr.ResultManager(exp_list=exp_list,
                      savedir_base=savedir_base,
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
kwargs = {
    'y_metric': y_metrics,
    'x_metric': x_metric,
    'log_metric_list': log_metric_list,
    'map_exp_list': map_exp_list,
    'title_list':title_list,
    'legend_list': legend_list,
    'avg_across': avg_across,
    'figsize': (20, 15),
    'legend_format': legend_format,
    'groupby_list': ['query_size']
}


# launch dashboard
rm.get_plot(**kwargs)
# Out:
# [<Figure size 1440x1080 with 1 Axes>]

# %%
print(df.columns)

df2 = df[df['heuristic'] == 'bald']
df2 = df2[df2['query_size'] == 100]
df2 = df2[df2['iterations'] == 20]
print(df2['exp_id'])
# Out:
# Index(['exp_id', 'lr', 'batch_size', 'model', 'seed', 'mu', 'reg_factor',
#        'backbone', 'num_classes', 'query_size', 'learning_epoch', 'heuristic',
#        'iterations', 'max_epoch', 'imagenet_pretraining', 'dataset'],
#       dtype='object')
# 49    35c5ac2afe08e5eb4d8806a6e2e5dab0
# 61    ad99b1b29a28f64e5b56f4362113eb51
# 73    cec110e03feb6a1e86b581c7cf6cb6bd
# 85    f20592490cd447a91a3aa6b66413e778
# Name: exp_id, dtype: object

# %%
print(df.columns)

df2 = df[df['heuristic'] == 'entropy']
df2 = df2[df2['query_size'] == 100]
df2 = df2[df2['iterations'] == 20]
print(df2['exp_id'])
# Out:
# Index(['exp_id', 'lr', 'batch_size', 'model', 'seed', 'mu', 'reg_factor',
#        'backbone', 'num_classes', 'query_size', 'learning_epoch', 'heuristic',
#        'iterations', 'max_epoch', 'imagenet_pretraining', 'dataset'],
#       dtype='object')
# 57    1e098eed78c5044fe470769409260b3e
# 69    9b994f8dd1eecae17fc80bd8310b7638
# 81    74d2a210dd3c5deed7f8ac792e86c374
# 93    8d830d94697b22bfcad42cb9d0012d23
# Name: exp_id, dtype: object
