# %%
# Specify variables
# sys.path.insert(local_haven)
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as hu

# please define the path to the experiments
savedir_base = '/mnt/datasets/public/research/adaptron_laplace/logs_borgy_finetune_haven/'
exp_list = None

# exp_config_name = <exp_config_name>
# exp_list = hu.load_py(exp_config_name).EXP_GROUPS['mnist']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None

# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
y_metrics='train_loss'
x_metric='epoch'
log_metric_list = ['train_loss']
map_exp_list = []
title_list=['dataset']
legend_list=['model']

# get experiments
rm = hr.ResultManager(exp_list=exp_list, 
                      savedir_base=savedir_base, 
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
score_lists = rm.get_score_lists()
# rm.get_score_table(columns=['dataset', 'exp_id'])


# launch dashboard
hj.get_dashboard(rm, vars(), wide_display=True)
# Out:
# 100%|██████████| 120/120 [00:00<00:00, 1013.73it/s]
# HBox(children=(Text(value='/mnt/datasets/public/research/adaptron_laplace/logs_borgy_finetune_haven/', descrip…
# Output()
# <style>.container { width:100% !important; }</style>
#     <style>
#         .output_scroll {
#             height: unset !important;
#             border-radius: unset !important;
#             -webkit-box-shadow: unset !important;
#             box-shadow: unset !important;
#         }
#     </style>

# %%
pandas.groupby(['alpha', 'beta']).mean()
# Out:
# [[{'epoch': 0,
#    'current_lr_0': 0.005,
#    'train_loss': 1.200021207332611,
#    'val_loss': 1.0422828282912573,
#    'val_accuracy': 0.6797111268341541,
#    'test_loss': 1.049289858142535,
#    'test_accuracy': 0.673755569756031,
#    'test_confidence': 0.008525355035599414},
#   {'epoch': 1,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0641857266426087,
#    'val_loss': 1.057471173107624,
#    'val_accuracy': 0.6644889035820961,
#    'test_loss': 1.0487895157933236,
#    'test_accuracy': 0.6723777924229701,
#    'test_confidence': 0.008592620408586263},
#   {'epoch': 2,
#    'current_lr_0': 0.005,
#    'train_loss': 1.3303639769554139,
#    'val_loss': 1.0600149521231652,
#    'val_accuracy': 0.6721777924398581,
#    'test_loss': 1.075647515654564,
#    'test_accuracy': 0.6523333469033241,
#    'test_confidence': 0.00820353922722982},
#   {'epoch': 3,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2676128625869751,
#    'val_loss': 1.0788424828648566,
#    'val_accuracy': 0.6627777926623821,
#    'test_loss': 1.0963405297199884,
#    'test_accuracy': 0.6448222364485264,
#    'test_confidence': 0.007731186354596871},
#   {'epoch': 4,
#    'current_lr_0': 0.005,
#    'train_loss': 1.3016712546348572,
#    'val_loss': 1.0824533051252365,
#    'val_accuracy': 0.6625555697828531,
#    'test_loss': 1.1146867777903875,
#    'test_accuracy': 0.6404666798561811,
#    'test_confidence': 0.008759890435752296},
#   {'epoch': 5,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1525038182735443,
#    'val_loss': 1.0672187462449074,
#    'val_accuracy': 0.669000013868014,
#    'test_loss': 1.0964571749170622,
#    'test_accuracy': 0.6507333471874396,
#    'test_confidence': 0.008308748301518953},
#   {'epoch': 6,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2195707082748413,
#    'val_loss': 1.0546178470055263,
#    'val_accuracy': 0.6820222383737564,
#    'test_loss': 1.0725672894716263,
#    'test_accuracy': 0.6628666802247365,
#    'test_confidence': 0.008233560001972241},
#   {'epoch': 7,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1989577770233155,
#    'val_loss': 1.0287141383687655,
#    'val_accuracy': 0.6903111256162325,
#    'test_loss': 1.0733057647943496,
#    'test_accuracy': 0.6643555696805318,
#    'test_confidence': 0.008324553152965035},
#   {'epoch': 8,
#    'current_lr_0': 0.005,
#    'train_loss': 1.195173156261444,
#    'val_loss': 1.0526130677262941,
#    'val_accuracy': 0.6777555697162946,
#    'test_loss': 1.082584912876288,
#    'test_accuracy': 0.6585333481927713,
#    'test_confidence': 0.008133600085717417},
#   {'epoch': 9,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2505993664264679,
#    'val_loss': 1.0725127468506495,
#    'val_accuracy': 0.660200014958779,
#    'test_loss': 1.078145690759023,
#    'test_accuracy': 0.6561777913570404,
#    'test_confidence': 0.008295248081385811},
#   {'epoch': 10,
#    'current_lr_0': 0.005,
#    'train_loss': 1.3603972315788269,
#    'val_loss': 1.0586646729707718,
#    'val_accuracy': 0.6729111256698768,
#    'test_loss': 1.073490826090177,
#    'test_accuracy': 0.6576444585621357,
#    'test_confidence': 0.008566419325788431},
#   {'epoch': 11,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2398444056510924,
#    'val_loss': 1.0902400057514507,
#    'val_accuracy': 0.6537333480020364,
#    'test_loss': 1.1076897821823757,
#    'test_accuracy': 0.6380000138282775,
#    'test_confidence': 0.00832667586681596},
#   {'epoch': 12,
#    'current_lr_0': 0.005,
#    'train_loss': 1.248157447576523,
#    'val_loss': 1.068444467286269,
#    'val_accuracy': 0.6672444581985474,
#    'test_loss': 1.0990950070818266,
#    'test_accuracy': 0.64848890264829,
#    'test_confidence': 0.008104467650428372},
#   {'epoch': 13,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2272135436534881,
#    'val_loss': 1.0557540040214857,
#    'val_accuracy': 0.6760000143448511,
#    'test_loss': 1.0928983134031296,
#    'test_accuracy': 0.6484889022509257,
#    'test_confidence': 0.008332206762638817},
#   {'epoch': 14,
#    'current_lr_0': 0.005,
#    'train_loss': 1.409711444377899,
#    'val_loss': 1.0470101204514504,
#    'val_accuracy': 0.6847777914007505,
#    'test_loss': 1.0928170931339265,
#    'test_accuracy': 0.6426000142594178,
#    'test_confidence': 0.00850886661861374},
#   {'epoch': 15,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2582443475723266,
#    'val_loss': 1.0638010626037915,
#    'val_accuracy': 0.668000014424324,
#    'test_loss': 1.0920108842849732,
#    'test_accuracy': 0.6486000136037667,
#    'test_confidence': 0.008155929108857147},
#   {'epoch': 16,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2286790609359741,
#    'val_loss': 1.0972465030352274,
#    'val_accuracy': 0.6546222361922264,
#    'test_loss': 1.114063463906447,
#    'test_accuracy': 0.6409111249446869,
#    'test_confidence': 0.00801753533121428},
#   {'epoch': 17,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1252960741519928,
#    'val_loss': 1.082628530462583,
#    'val_accuracy': 0.6581111244360606,
#    'test_loss': 1.0712602066993713,
#    'test_accuracy': 0.660777790993452,
#    'test_confidence': 0.008159270474639635},
#   {'epoch': 18,
#    'current_lr_0': 0.005,
#    'train_loss': 1.2463376641273498,
#    'val_loss': 1.0622658036152521,
#    'val_accuracy': 0.6648666820426782,
#    'test_loss': 1.0708996220429738,
#    'test_accuracy': 0.6594444594780604,
#    'test_confidence': 0.00872504897672227},
#   {'epoch': 19,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.2079753279685974,
#    'val_loss': 1.0618849955995877,
#    'val_accuracy': 0.6682222364346186,
#    'test_loss': 1.070959710975488,
#    'test_accuracy': 0.6592666820188363,
#    'test_confidence': 0.007804827851130109},
#   {'epoch': 20,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.2192406177520752,
#    'val_loss': 1.0550803479552269,
#    'val_accuracy': 0.6731555706759293,
#    'test_loss': 1.0677930578589439,
#    'test_accuracy': 0.6647777922948201,
#    'test_confidence': 0.008209738735255543},
#   {'epoch': 21,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.3136105179786681,
#    'val_loss': 1.060838613708814,
#    'val_accuracy': 0.664955568710963,
#    'test_loss': 1.0656921420494716,
#    'test_accuracy': 0.6622666816910108,
#    'test_confidence': 0.008349347133531701},
#   {'epoch': 22,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.3013579607009889,
#    'val_loss': 1.0458093647162119,
#    'val_accuracy': 0.6749333485464255,
#    'test_loss': 1.0560639004906018,
#    'test_accuracy': 0.6678889035185178,
#    'test_confidence': 0.008563376989223956},
#   {'epoch': 23,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.155980223417282,
#    'val_loss': 1.0430552436908087,
#    'val_accuracy': 0.6736222366988659,
#    'test_loss': 1.0524070929487546,
#    'test_accuracy': 0.6745333487292131,
#    'test_confidence': 0.008312990167223002},
#   {'epoch': 24,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1754016935825349,
#    'val_loss': 1.0344910526275635,
#    'val_accuracy': 0.6857111256321271,
#    'test_loss': 1.0675008218487103,
#    'test_accuracy': 0.6599777914583683,
#    'test_confidence': 0.008630403635860024},
#   {'epoch': 25,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0666766464710236,
#    'val_loss': 1.0335655480623245,
#    'val_accuracy': 0.6921555704871813,
#    'test_loss': 1.05931380768617,
#    'test_accuracy': 0.6678889038662116,
#    'test_confidence': 0.008300911462617527},
#   {'epoch': 26,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1953514754772185,
#    'val_loss': 1.0382342317700386,
#    'val_accuracy': 0.6848889037966728,
#    'test_loss': 1.0565368968248368,
#    'test_accuracy': 0.6719333478311698,
#    'test_confidence': 0.008361532061479353},
#   {'epoch': 27,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1889496326446534,
#    'val_loss': 1.0429933164517085,
#    'val_accuracy': 0.6802444584170977,
#    'test_loss': 1.0645679902036984,
#    'test_accuracy': 0.6631111258765062,
#    'test_confidence': 0.008249194278727239},
#   {'epoch': 28,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0539589762687682,
#    'val_loss': 1.0177719700336456,
#    'val_accuracy': 0.6975111253062884,
#    'test_loss': 1.0597205642859142,
#    'test_accuracy': 0.666133348296086,
#    'test_confidence': 0.008427177240836865},
#   {'epoch': 29,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1756886541843414,
#    'val_loss': 1.0335660143693288,
#    'val_accuracy': 0.6874666811029116,
#    'test_loss': 1.053301852842172,
#    'test_accuracy': 0.6677555698653063,
#    'test_confidence': 0.008120484077110976},
#   {'epoch': 30,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0380433738231658,
#    'val_loss': 1.026107486486435,
#    'val_accuracy': 0.6906666816274325,
#    'test_loss': 1.0547219782074293,
#    'test_accuracy': 0.6694666813313961,
#    'test_confidence': 0.008073421813807023},
#   {'epoch': 31,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1369546413421632,
#    'val_loss': 1.0159689425428708,
#    'val_accuracy': 0.7004000153640906,
#    'test_loss': 1.0415356611212094,
#    'test_accuracy': 0.6790000148614248,
#    'test_confidence': 0.008606454049752575},
#   {'epoch': 32,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1397798478603363,
#    'val_loss': 1.0286368862787882,
#    'val_accuracy': 0.6874444594979287,
#    'test_loss': 1.0486074541012447,
#    'test_accuracy': 0.6758000144362449,
#    'test_confidence': 0.008204218208808817},
#   {'epoch': 33,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.2471107125282288,
#    'val_loss': 1.0303420448303222,
#    'val_accuracy': 0.6892666814972958,
#    'test_loss': 1.051524472037951,
#    'test_accuracy': 0.6680000145733357,
#    'test_confidence': 0.00893773951695777},
#   {'epoch': 34,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0381744742393493,
#    'val_loss': 1.0255529715617497,
#    'val_accuracy': 0.6879333481689294,
#    'test_loss': 1.0355315805474916,
#    'test_accuracy': 0.6817777921756109,
#    'test_confidence': 0.007835220706129064},
#   {'epoch': 35,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0400994777679444,
#    'val_loss': 1.0370314327875774,
#    'val_accuracy': 0.685644458582004,
#    'test_loss': 1.045058698852857,
#    'test_accuracy': 0.678577793041865,
#    'test_confidence': 0.008064393488133885},
#   {'epoch': 36,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1063968181610107,
#    'val_loss': 1.036171571612358,
#    'val_accuracy': 0.6888666808108489,
#    'test_loss': 1.0453974071145058,
#    'test_accuracy': 0.6760444590946039,
#    'test_confidence': 0.008202558760931735},
#   {'epoch': 37,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0133046686649323,
#    'val_loss': 1.023409458597501,
#    'val_accuracy': 0.6968000169595082,
#    'test_loss': 1.0440423066417377,
#    'test_accuracy': 0.6786889036993186,
#    'test_confidence': 0.008039991565239303},
#   {'epoch': 38,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.06798654794693,
#    'val_loss': 1.0162694924076399,
#    'val_accuracy': 0.697000014781952,
#    'test_loss': 1.0490844166278839,
#    'test_accuracy': 0.6741777921219667,
#    'test_confidence': 0.008263089545500658},
#   {'epoch': 39,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.034254437685013,
#    'val_loss': 1.0265368276834488,
#    'val_accuracy': 0.6935111258924007,
#    'test_loss': 1.0564219761888187,
#    'test_accuracy': 0.6708889033397039,
#    'test_confidence': 0.008062815223858705},
#   {'epoch': 40,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0853288173675537,
#    'val_loss': 1.0234630103905995,
#    'val_accuracy': 0.6910444594919681,
#    'test_loss': 1.0466772145032883,
#    'test_accuracy': 0.6765777918199698,
#    'test_confidence': 0.00868774271891075},
#   {'epoch': 41,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.0180693507194518,
#    'val_loss': 1.0233019947012265,
#    'val_accuracy': 0.6958444594343504,
#    'test_loss': 1.0528400267163913,
#    'test_accuracy': 0.6754000146190325,
#    'test_confidence': 0.00829397048697762},
#   {'epoch': 42,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.1677160561084747,
#    'val_loss': 1.020253419180711,
#    'val_accuracy': 0.6910222386320432,
#    'test_loss': 1.0441116096576055,
#    'test_accuracy': 0.6760889030992985,
#    'test_confidence': 0.008825215940420105},
#   {'epoch': 43,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.1326376259326936,
#    'val_loss': 1.0266718793908756,
#    'val_accuracy': 0.6916889031479756,
#    'test_loss': 1.0406165048480034,
#    'test_accuracy': 0.6810666818916797,
#    'test_confidence': 0.008167707628800968},
#   {'epoch': 44,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.0105004489421845,
#    'val_loss': 1.0319015796979267,
#    'val_accuracy': 0.6868889039258163,
#    'test_loss': 1.0481482221682867,
#    'test_accuracy': 0.6740889033178489,
#    'test_confidence': 0.008011807415532797},
#   {'epoch': 45,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.0872980296611785,
#    'val_loss': 1.0180137760440509,
#    'val_accuracy': 0.6994889031350613,
#    'test_loss': 1.0419393442074458,
#    'test_accuracy': 0.6778222359716892,
#    'test_confidence': 0.008179126056339022},
#   {'epoch': 46,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.0959222137928009,
#    'val_loss': 1.0149731353918712,
#    'val_accuracy': 0.6982444602747758,
#    'test_loss': 1.0397144042452175,
#    'test_accuracy': 0.6820889031390349,
#    'test_confidence': 0.008378614871282936},
#   {'epoch': 47,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.023155105113983,
#    'val_loss': 1.021768189072609,
#    'val_accuracy': 0.6955555711686611,
#    'test_loss': 1.0438864103953043,
#    'test_accuracy': 0.6777777924637,
#    'test_confidence': 0.008472368735169005},
#   {'epoch': 48,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.1045592784881593,
#    'val_loss': 1.0189691911141077,
#    'val_accuracy': 0.6956889042754968,
#    'test_loss': 1.0447224271297455,
#    'test_accuracy': 0.6789333486557007,
#    'test_confidence': 0.0077707720130050645},
#   {'epoch': 49,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.1029922604560851,
#    'val_loss': 1.0188358372449875,
#    'val_accuracy': 0.698866682201624,
#    'test_loss': 1.0385040164987247,
#    'test_accuracy': 0.6846000148852667,
#    'test_confidence': 0.008243207911267507},
#   {'epoch': 50,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.0530775904655456,
#    'val_loss': 1.0193764584263165,
#    'val_accuracy': 0.6984000158309936,
#    'test_loss': 1.0544330752889315,
#    'test_accuracy': 0.6699333479503791,
#    'test_confidence': 0.008454295048044813},
#   {'epoch': 51,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.0894235491752624,
#    'val_loss': 1.010981139143308,
#    'val_accuracy': 0.6990666825075944,
#    'test_loss': 1.0397373896837234,
#    'test_accuracy': 0.679066681911548,
#    'test_confidence': 0.008050646550463334},
#   {'epoch': 52,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.9982174456119537,
#    'val_loss': 1.0251042440533638,
#    'val_accuracy': 0.6902444589138031,
#    'test_loss': 1.0414390496412913,
#    'test_accuracy': 0.6777777928610643,
#    'test_confidence': 0.008080483797778142},
#   {'epoch': 53,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.9494805991649627,
#    'val_loss': 1.0176697353521982,
#    'val_accuracy': 0.6997555705904961,
#    'test_loss': 1.0449587554732958,
#    'test_accuracy': 0.6757777938246727,
#    'test_confidence': 0.008081014959814788},
#   {'epoch': 54,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0984480857849122,
#    'val_loss': 1.0291215204199156,
#    'val_accuracy': 0.6908889036625624,
#    'test_loss': 1.0534680965542793,
#    'test_accuracy': 0.6719555696845054,
#    'test_confidence': 0.008413418499118884},
#   {'epoch': 55,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0251621782779694,
#    'val_loss': 1.0218792953093847,
#    'val_accuracy': 0.6975777925550938,
#    'test_loss': 1.0439736275871594,
#    'test_accuracy': 0.6822000146905581,
#    'test_confidence': 0.008322340266309887},
#   {'epoch': 56,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.1115998864173888,
#    'val_loss': 1.0221617901325226,
#    'val_accuracy': 0.6936222378412883,
#    'test_loss': 1.0405131526788076,
#    'test_accuracy': 0.6783555697401364,
#    'test_confidence': 0.008262313669304812},
#   {'epoch': 57,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0758489847183228,
#    'val_loss': 1.0247811190287273,
#    'val_accuracy': 0.6914000158011914,
#    'test_loss': 1.0515958892305692,
#    'test_accuracy': 0.675888903538386,
#    'test_confidence': 0.007699464568904091},
#   {'epoch': 58,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0380903482437134,
#    'val_loss': 1.025529025197029,
#    'val_accuracy': 0.6913555713991324,
#    'test_loss': 1.0470280770460765,
#    'test_accuracy': 0.6756222366789977,
#    'test_confidence': 0.007630561784832526},
#   {'epoch': 59,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0385495185852052,
#    'val_loss': 1.0216698494553567,
#    'val_accuracy': 0.6968666827181975,
#    'test_loss': 1.055751433769862,
#    'test_accuracy': 0.6737555699050426,
#    'test_confidence': 0.008269298776688621},
#   {'epoch': 60,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.073409867286682,
#    'val_loss': 1.0186396963397661,
#    'val_accuracy': 0.6994666823744774,
#    'test_loss': 1.0523415573438009,
#    'test_accuracy': 0.6756222361822923,
#    'test_confidence': 0.008039412510179339},
#   {'epoch': 61,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0000537037849426,
#    'val_loss': 1.0242413530747096,
#    'val_accuracy': 0.6969555706282456,
#    'test_loss': 1.0604867487152418,
#    'test_accuracy': 0.6660666810969512,
#    'test_confidence': 0.008130203477211904},
#   {'epoch': 62,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.9957244336605072,
#    'val_loss': 1.0156932894388835,
#    'val_accuracy': 0.6998889045417309,
#    'test_loss': 1.0501322987675668,
#    'test_accuracy': 0.6754444597164789,
#    'test_confidence': 0.008031178231073945},
#   {'epoch': 63,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.0828915119171143,
#    'val_loss': 1.01605583379666,
#    'val_accuracy': 0.6993333483735721,
#    'test_loss': 1.0522353637218476,
#    'test_accuracy': 0.6707777922352155,
#    'test_confidence': 0.008317902327164943},
#   {'epoch': 64,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.079306674003601,
#    'val_loss': 1.0144947198033334,
#    'val_accuracy': 0.6988444610933463,
#    'test_loss': 1.0519662250081698,
#    'test_accuracy': 0.673200014680624,
#    'test_confidence': 0.00860892702603242}],
#  [{'epoch': 0,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1905319094657898,
#    'val_loss': 0.9349707978963852,
#    'val_accuracy': 0.8570889089504877,
#    'test_loss': 0.9552598262826602,
#    'test_accuracy': 0.8630000207821528,
#    'test_confidence': 0.004586046310824904},
#   {'epoch': 1,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0284221470355988,
#    'val_loss': 0.9422682187954585,
#    'val_accuracy': 0.8611333549022675,
#    'test_loss': 0.9742149362961451,
#    'test_accuracy': 0.8531333527962367,
#    'test_confidence': 0.0048029150338334305},
#   {'epoch': 2,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0438639879226685,
#    'val_loss': 0.9530966207385063,
#    'val_accuracy': 0.8589777983228366,
#    'test_loss': 0.9831293613711993,
#    'test_accuracy': 0.8599333542585373,
#    'test_confidence': 0.004780841547848999},
#   {'epoch': 3,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0896307170391082,
#    'val_loss': 0.9462722234924634,
#    'val_accuracy': 0.8578444654742877,
#    'test_loss': 0.9951373853286107,
#    'test_accuracy': 0.8539555761218071,
#    'test_confidence': 0.004698464008708972},
#   {'epoch': 4,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1122584760189056,
#    'val_loss': 0.9471017655730247,
#    'val_accuracy': 0.8558444647987684,
#    'test_loss': 0.9814784467220307,
#    'test_accuracy': 0.8588889090220133,
#    'test_confidence': 0.004744356829268249},
#   {'epoch': 5,
#    'current_lr_0': 0.005,
#    'train_loss': 1.021982729434967,
#    'val_loss': 0.9395153505603472,
#    'val_accuracy': 0.8606000200907389,
#    'test_loss': 0.9779697054624558,
#    'test_accuracy': 0.8596222425500551,
#    'test_confidence': 0.004675837476232112},
#   {'epoch': 6,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9832441568374634,
#    'val_loss': 0.9398968456188838,
#    'val_accuracy': 0.8591555766264598,
#    'test_loss': 0.9795652930935224,
#    'test_accuracy': 0.8563777977228164,
#    'test_confidence': 0.004639832958692681},
#   {'epoch': 7,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1099293529987335,
#    'val_loss': 0.939162593682607,
#    'val_accuracy': 0.8613777988155683,
#    'test_loss': 0.9817517881592115,
#    'test_accuracy': 0.8547111321489016,
#    'test_confidence': 0.004864239626120836},
#   {'epoch': 8,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0015867352485657,
#    'val_loss': 0.9377377994855245,
#    'val_accuracy': 0.8612666892011961,
#    'test_loss': 0.9798025686542193,
#    'test_accuracy': 0.8542000195384025,
#    'test_confidence': 0.005030614995205069},
#   {'epoch': 9,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0479837834835053,
#    'val_loss': 0.9389735015233358,
#    'val_accuracy': 0.8556444653868676,
#    'test_loss': 0.9702046042680741,
#    'test_accuracy': 0.8566444658239682,
#    'test_confidence': 0.004656309089710386},
#   {'epoch': 10,
#    'current_lr_0': 0.005,
#    'train_loss': 1.058823400735855,
#    'val_loss': 0.9334391694267591,
#    'val_accuracy': 0.8605555767814318,
#    'test_loss': 0.9741095745563507,
#    'test_accuracy': 0.8548222428560257,
#    'test_confidence': 0.004684805490797029},
#   {'epoch': 11,
#    'current_lr_0': 0.005,
#    'train_loss': 1.12414191365242,
#    'val_loss': 0.9412206267317136,
#    'val_accuracy': 0.8558666869004568,
#    'test_loss': 0.9768611459930738,
#    'test_accuracy': 0.8530000208814938,
#    'test_confidence': 0.00492679602393643},
#   {'epoch': 12,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1079262793064117,
#    'val_loss': 0.9536059074600538,
#    'val_accuracy': 0.860488910873731,
#    'test_loss': 0.9779738527536392,
#    'test_accuracy': 0.850866687297821,
#    'test_confidence': 0.0049151337466494084},
#   {'epoch': 13,
#    'current_lr_0': 0.005,
#    'train_loss': 1.021882677078247,
#    'val_loss': 0.9505264766017596,
#    'val_accuracy': 0.8591777989268303,
#    'test_loss': 0.9691007812817891,
#    'test_accuracy': 0.8590000203251839,
#    'test_confidence': 0.004997541568266237},
#   {'epoch': 14,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9612901151180268,
#    'val_loss': 0.9518638942639033,
#    'val_accuracy': 0.8604666869839033,
#    'test_loss': 0.9818442408243815,
#    'test_accuracy': 0.856511130730311,
#    'test_confidence': 0.004800144160190456},
#   {'epoch': 15,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0065662622451783,
#    'val_loss': 0.9381401827931404,
#    'val_accuracy': 0.8606889092922211,
#    'test_loss': 0.9666739418109258,
#    'test_accuracy': 0.8562889102101326,
#    'test_confidence': 0.004684805437646103},
#   {'epoch': 16,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0110216736793518,
#    'val_loss': 0.9355191187063853,
#    'val_accuracy': 0.8602000204722087,
#    'test_loss': 0.9639499528209369,
#    'test_accuracy': 0.8571111314495404,
#    'test_confidence': 0.004920054963017712},
#   {'epoch': 17,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0034472584724425,
#    'val_loss': 0.9359694967667261,
#    'val_accuracy': 0.8616000206271808,
#    'test_loss': 0.9575029682119688,
#    'test_accuracy': 0.8614000211159388,
#    'test_confidence': 0.0048295593054432555},
#   {'epoch': 18,
#    'current_lr_0': 0.005,
#    'train_loss': 0.925467848777771,
#    'val_loss': 0.9370818475882212,
#    'val_accuracy': 0.8619333550333976,
#    'test_loss': 0.9665439998110136,
#    'test_accuracy': 0.8560000209013621,
#    'test_confidence': 0.004736743511332132},
#   {'epoch': 19,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0385073900222779,
#    'val_loss': 0.9441019110878308,
#    'val_accuracy': 0.8612000216046969,
#    'test_loss': 0.9785858291387558,
#    'test_accuracy': 0.8571333544452985,
#    'test_confidence': 0.00466577811696081},
#   {'epoch': 20,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9548970341682435,
#    'val_loss': 0.9333159871896108,
#    'val_accuracy': 0.8630889093875885,
#    'test_loss': 0.9703902704517047,
#    'test_accuracy': 0.8626444651683172,
#    'test_confidence': 0.004633389085472823},
#   {'epoch': 21,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0072767555713653,
#    'val_loss': 0.9226807959874471,
#    'val_accuracy': 0.8658444658915202,
#    'test_loss': 0.9784645185867945,
#    'test_accuracy': 0.8560666870077451,
#    'test_confidence': 0.0049632867272736015},
#   {'epoch': 22,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9465471148490906,
#    'val_loss': 0.9282282215356826,
#    'val_accuracy': 0.8667111320296923,
#    'test_loss': 0.9791014646490415,
#    'test_accuracy': 0.8590666863322258,
#    'test_confidence': 0.004568004385044189},
#   {'epoch': 23,
#    'current_lr_0': 0.005,
#    'train_loss': 0.955921059846878,
#    'val_loss': 0.9395523609717688,
#    'val_accuracy': 0.8635111312071483,
#    'test_loss': 0.9829615380366643,
#    'test_accuracy': 0.8557333545883496,
#    'test_confidence': 0.004560375695055275},
#   {'epoch': 24,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9856195032596589,
#    'val_loss': 0.9335249877969424,
#    'val_accuracy': 0.8638000208139419,
#    'test_loss': 0.9701532058914503,
#    'test_accuracy': 0.8624889095624287,
#    'test_confidence': 0.004529844732733483},
#   {'epoch': 25,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9993455946445465,
#    'val_loss': 0.9328016916910807,
#    'val_accuracy': 0.8658222429951032,
#    'test_loss': 0.9671727741758028,
#    'test_accuracy': 0.8644889093438785,
#    'test_confidence': 0.004625887826633194},
#   {'epoch': 26,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0167168498039245,
#    'val_loss': 0.9288965257008871,
#    'val_accuracy': 0.8623555769522985,
#    'test_loss': 0.9651263254880905,
#    'test_accuracy': 0.8671555764476458,
#    'test_confidence': 0.004629021233933942},
#   {'epoch': 27,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9163090884685516,
#    'val_loss': 0.9219379206498464,
#    'val_accuracy': 0.8635555759072304,
#    'test_loss': 0.9697510366638501,
#    'test_accuracy': 0.8596444648504257,
#    'test_confidence': 0.004734643240763765},
#   {'epoch': 28,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0071664988994598,
#    'val_loss': 0.9213517108559608,
#    'val_accuracy': 0.8671777990460395,
#    'test_loss': 0.959686255355676,
#    'test_accuracy': 0.8587555752197902,
#    'test_confidence': 0.004838516030502893},
#   {'epoch': 29,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9679831743240357,
#    'val_loss': 0.9334867120782534,
#    'val_accuracy': 0.8628889105717341,
#    'test_loss': 0.9528416335582733,
#    'test_accuracy': 0.8591777989268303,
#    'test_confidence': 0.004781187467544335},
#   {'epoch': 30,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9981455147266388,
#    'val_loss': 0.9404877337813378,
#    'val_accuracy': 0.8612444657087326,
#    'test_loss': 0.9574928517142932,
#    'test_accuracy': 0.8584666862090429,
#    'test_confidence': 0.004936359461607628},
#   {'epoch': 31,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9105093836784363,
#    'val_loss': 0.9344362451632817,
#    'val_accuracy': 0.8639555770158768,
#    'test_loss': 0.96140954464674,
#    'test_accuracy': 0.8620889104406039,
#    'test_confidence': 0.0045588512969794905},
#   {'epoch': 32,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9342326045036315,
#    'val_loss': 0.9287871380647024,
#    'val_accuracy': 0.8655555777748426,
#    'test_loss': 0.9580013570189476,
#    'test_accuracy': 0.8653555762767792,
#    'test_confidence': 0.004467524353371972},
#   {'epoch': 33,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9532376885414123,
#    'val_loss': 0.9416101055343946,
#    'val_accuracy': 0.8577333555618922,
#    'test_loss': 0.9555104677875836,
#    'test_accuracy': 0.8624889099597931,
#    'test_confidence': 0.004652434369246827},
#   {'epoch': 34,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0108624160289765,
#    'val_loss': 0.9305675333738327,
#    'val_accuracy': 0.8650222430626552,
#    'test_loss': 0.9534338043133418,
#    'test_accuracy': 0.8636222431063652,
#    'test_confidence': 0.0045425938436064964},
#   {'epoch': 35,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8906098186969758,
#    'val_loss': 0.9251440996925037,
#    'val_accuracy': 0.86482224325339,
#    'test_loss': 0.9653111469745635,
#    'test_accuracy': 0.8567777990301451,
#    'test_confidence': 0.004522650375212262},
#   {'epoch': 36,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0246889770030976,
#    'val_loss': 0.9300820682446161,
#    'val_accuracy': 0.8673111323515574,
#    'test_loss': 0.9606449623902639,
#    'test_accuracy': 0.8597333546479543,
#    'test_confidence': 0.004870543847747439},
#   {'epoch': 37,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0091600120067596,
#    'val_loss': 0.9244642983873685,
#    'val_accuracy': 0.8678889095783233,
#    'test_loss': 0.96053930580616,
#    'test_accuracy': 0.8619777983427048,
#    'test_confidence': 0.004580462723584213},
#   {'epoch': 38,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9360922515392304,
#    'val_loss': 0.9401208654046058,
#    'val_accuracy': 0.8609777996937434,
#    'test_loss': 0.9546804283062617,
#    'test_accuracy': 0.8608000212907791,
#    'test_confidence': 0.0046779427231284},
#   {'epoch': 39,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9138297319412232,
#    'val_loss': 0.9296841398874919,
#    'val_accuracy': 0.8646666886409123,
#    'test_loss': 0.9533435566226641,
#    'test_accuracy': 0.8616666886210441,
#    'test_confidence': 0.004561225994072762},
#   {'epoch': 40,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9683824121952057,
#    'val_loss': 0.9306006491184234,
#    'val_accuracy': 0.8611333540081978,
#    'test_loss': 0.9578078608711561,
#    'test_accuracy': 0.8625333533684413,
#    'test_confidence': 0.004774523189674139},
#   {'epoch': 41,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9323598802089691,
#    'val_loss': 0.9367309596141179,
#    'val_accuracy': 0.8583555763959885,
#    'test_loss': 0.95303054134051,
#    'test_accuracy': 0.8641111325224241,
#    'test_confidence': 0.004733310379465888},
#   {'epoch': 42,
#    'current_lr_0': 0.005,
#    'train_loss': 0.945655632019043,
#    'val_loss': 0.9346500244736672,
#    'val_accuracy': 0.861511132021745,
#    'test_loss': 0.9558193176984787,
#    'test_accuracy': 0.8601555766661962,
#    'test_confidence': 0.004807888533595723},
#   {'epoch': 43,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8846111834049225,
#    'val_loss': 0.9291889915863673,
#    'val_accuracy': 0.8651333538691203,
#    'test_loss': 0.9589243725935618,
#    'test_accuracy': 0.859355576535066,
#    'test_confidence': 0.00460534497662599},
#   {'epoch': 44,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8955332815647126,
#    'val_loss': 0.926351608534654,
#    'val_accuracy': 0.8672222426533699,
#    'test_loss': 0.96082670489947,
#    'test_accuracy': 0.858711131811142,
#    'test_confidence': 0.004666213224191146},
#   {'epoch': 45,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9637531936168671,
#    'val_loss': 0.9222569596767426,
#    'val_accuracy': 0.8691333542267482,
#    'test_loss': 0.955738811691602,
#    'test_accuracy': 0.8611333548029264,
#    'test_confidence': 0.004388344018341494},
#   {'epoch': 46,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9427326202392579,
#    'val_loss': 0.92582440584898,
#    'val_accuracy': 0.8721111328403155,
#    'test_loss': 0.9530846426884333,
#    'test_accuracy': 0.8661333535114925,
#    'test_confidence': 0.004583011501088614},
#   {'epoch': 47,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9091826856136322,
#    'val_loss': 0.9312241191665331,
#    'val_accuracy': 0.8715111314256986,
#    'test_loss': 0.9585123599569003,
#    'test_accuracy': 0.8617555769284566,
#    'test_confidence': 0.004698241698500248},
#   {'epoch': 48,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9004589140415191,
#    'val_loss': 0.9405222840110461,
#    'val_accuracy': 0.8663111312190691,
#    'test_loss': 0.9613301168878873,
#    'test_accuracy': 0.8574444640676181,
#    'test_confidence': 0.004424345352580201},
#   {'epoch': 49,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8928138077259063,
#    'val_loss': 0.9316753839453061,
#    'val_accuracy': 0.8681111319859822,
#    'test_loss': 0.9565173713366191,
#    'test_accuracy': 0.8593111320336659,
#    'test_confidence': 0.004653931975494484},
#   {'epoch': 50,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9468644142150879,
#    'val_loss': 0.9255925901730855,
#    'val_accuracy': 0.8674889104564985,
#    'test_loss': 0.9514320235451063,
#    'test_accuracy': 0.8642666877309482,
#    'test_confidence': 0.004505660457961924},
#   {'epoch': 51,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8816551029682159,
#    'val_loss': 0.9210063734650612,
#    'val_accuracy': 0.8694444648424784,
#    'test_loss': 0.9519754329323769,
#    'test_accuracy': 0.8616000207265219,
#    'test_confidence': 0.0044577259190121945},
#   {'epoch': 52,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8775919795036315,
#    'val_loss': 0.9312857062617937,
#    'val_accuracy': 0.8665333554148674,
#    'test_loss': 0.9460381853580475,
#    'test_accuracy': 0.8655111322800318,
#    'test_confidence': 0.004652516522063995},
#   {'epoch': 53,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8902110874652862,
#    'val_loss': 0.9319470692674319,
#    'val_accuracy': 0.8638444654146831,
#    'test_loss': 0.9476604145765305,
#    'test_accuracy': 0.860022244254748,
#    'test_confidence': 0.004764053871717345},
#   {'epoch': 54,
#    'current_lr_0': 0.005,
#    'train_loss': 0.859246426820755,
#    'val_loss': 0.92902268131574,
#    'val_accuracy': 0.8605333542823792,
#    'test_loss': 0.9446516548593838,
#    'test_accuracy': 0.8675777983665466,
#    'test_confidence': 0.004408413064523046},
#   {'epoch': 55,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9139608681201935,
#    'val_loss': 0.9332560494542121,
#    'val_accuracy': 0.8646222433447838,
#    'test_loss': 0.944175523420175,
#    'test_accuracy': 0.8643111333250999,
#    'test_confidence': 0.0046532914592236595},
#   {'epoch': 56,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8475107312202453,
#    'val_loss': 0.9256205813090006,
#    'val_accuracy': 0.8682666875918706,
#    'test_loss': 0.9540905661384265,
#    'test_accuracy': 0.8616444665193558,
#    'test_confidence': 0.004755811949783811},
#   {'epoch': 57,
#    'current_lr_0': 0.005,
#    'train_loss': 0.8135742664337158,
#    'val_loss': 0.9300036195913951,
#    'val_accuracy': 0.8653555777668953,
#    'test_loss': 0.9523311021924019,
#    'test_accuracy': 0.8632444655895233,
#    'test_confidence': 0.004706939155558693},
#   {'epoch': 58,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8482512652873992,
#    'val_loss': 0.9217652729153634,
#    'val_accuracy': 0.8676000229517619,
#    'test_loss': 0.9417626440525055,
#    'test_accuracy': 0.8660000205039978,
#    'test_confidence': 0.004677261605869464},
#   {'epoch': 59,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8638134300708771,
#    'val_loss': 0.9229574197530747,
#    'val_accuracy': 0.8689333553115527,
#    'test_loss': 0.9473286983370781,
#    'test_accuracy': 0.8617777972420056,
#    'test_confidence': 0.0047277395662221125},
#   {'epoch': 60,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.85705925822258,
#    'val_loss': 0.9296577460567157,
#    'val_accuracy': 0.8658666882912318,
#    'test_loss': 0.9466218843062719,
#    'test_accuracy': 0.8612666873137156,
#    'test_confidence': 0.004892201862681412},
#   {'epoch': 61,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.7803795635700226,
#    'val_loss': 0.9245818072557449,
#    'val_accuracy': 0.8678000204761823,
#    'test_loss': 0.9421958063046137,
#    'test_accuracy': 0.8698666880528132,
#    'test_confidence': 0.004743071223362862},
#   {'epoch': 62,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.9376886308193206,
#    'val_loss': 0.9223595490058263,
#    'val_accuracy': 0.8714889092246692,
#    'test_loss': 0.9465809061129888,
#    'test_accuracy': 0.8614666882157326,
#    'test_confidence': 0.004968464841647939},
#   {'epoch': 63,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8252857446670532,
#    'val_loss': 0.9259728813171386,
#    'val_accuracy': 0.8684666883945465,
#    'test_loss': 0.9379515579342842,
#    'test_accuracy': 0.8678000217676163,
#    'test_confidence': 0.0044686914903469205},
#   {'epoch': 64,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.840491783618927,
#    'val_loss': 0.9196917551755905,
#    'val_accuracy': 0.8670666879415512,
#    'test_loss': 0.9453651199738184,
#    'test_accuracy': 0.8619333548347156,
#    'test_confidence': 0.004601363486101341},
#   {'epoch': 65,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8376874089241028,
#    'val_loss': 0.9178346784909567,
#    'val_accuracy': 0.8732444666822752,
#    'test_loss': 0.9411649099985758,
#    'test_accuracy': 0.8683333551883697,
#    'test_confidence': 0.004481686023267367},
#   {'epoch': 66,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.7876944184303284,
#    'val_loss': 0.9083089288075765,
#    'val_accuracy': 0.8779111335674922,
#    'test_loss': 0.9402865113814672,
#    'test_accuracy': 0.8645777987440427,
#    'test_confidence': 0.004510043800709692},
#   {'epoch': 67,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.820400846004486,
#    'val_loss': 0.9202367808421453,
#    'val_accuracy': 0.8701111325621604,
#    'test_loss': 0.9464630315701167,
#    'test_accuracy': 0.8628444639841716,
#    'test_confidence': 0.004709415075415498},
#   {'epoch': 68,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8460792422294616,
#    'val_loss': 0.925859189927578,
#    'val_accuracy': 0.8723555773496627,
#    'test_loss': 0.9439743599295616,
#    'test_accuracy': 0.8651333543658256,
#    'test_confidence': 0.0045550394867335114},
#   {'epoch': 69,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8578752160072327,
#    'val_loss': 0.9264369945724805,
#    'val_accuracy': 0.8698000208536784,
#    'test_loss': 0.9450591742992401,
#    'test_accuracy': 0.8629111313819885,
#    'test_confidence': 0.004715630615020768},
#   {'epoch': 70,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8651454269886016,
#    'val_loss': 0.9174491794904073,
#    'val_accuracy': 0.8732222432891528,
#    'test_loss': 0.9425222450494766,
#    'test_accuracy': 0.865844465692838,
#    'test_confidence': 0.004685457057214426},
#   {'epoch': 71,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.900332635641098,
#    'val_loss': 0.9261208174626032,
#    'val_accuracy': 0.8694222443302473,
#    'test_loss': 0.9360607592264811,
#    'test_accuracy': 0.8716000213225683,
#    'test_confidence': 0.004428203468951939},
#   {'epoch': 72,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8672717988491059,
#    'val_loss': 0.9150755262374878,
#    'val_accuracy': 0.8739778000116348,
#    'test_loss': 0.9359702154994011,
#    'test_accuracy': 0.8691333552201589,
#    'test_confidence': 0.004609044414740986},
#   {'epoch': 73,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8539811849594117,
#    'val_loss': 0.9137713638941447,
#    'val_accuracy': 0.8734889114896457,
#    'test_loss': 0.9399334598580996,
#    'test_accuracy': 0.8663111320137977,
#    'test_confidence': 0.004615478537784267},
#   {'epoch': 74,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8171687245368957,
#    'val_loss': 0.9160526908437411,
#    'val_accuracy': 0.8742000220219294,
#    'test_loss': 0.9444624540209771,
#    'test_accuracy': 0.865711132188638,
#    'test_confidence': 0.004720992388891105},
#   {'epoch': 75,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.9489345967769622,
#    'val_loss': 0.9139132929841677,
#    'val_accuracy': 0.8743111325303713,
#    'test_loss': 0.9415541459123293,
#    'test_accuracy': 0.8663111339012782,
#    'test_confidence': 0.00478873437924761},
#   {'epoch': 76,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8139812707901001,
#    'val_loss': 0.920247061252594,
#    'val_accuracy': 0.8755555763840676,
#    'test_loss': 0.9435873182614645,
#    'test_accuracy': 0.8665777982274692,
#    'test_confidence': 0.004737141025555825},
#   {'epoch': 77,
#    'current_lr_0': 0.0005,
#    'train_loss': 0.8234207153320312,
#    'val_loss': 0.92495411247015,
#    'val_accuracy': 0.8714889102180798,
#    'test_loss': 0.939118838707606,
#    'test_accuracy': 0.8659555768966675,
#    'test_confidence': 0.00479803212535762},
#   {'epoch': 78,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.7661613583564758,
#    'val_loss': 0.9198560380935669,
#    'val_accuracy': 0.8709333560864131,
#    'test_loss': 0.9421990243593852,
#    'test_accuracy': 0.8670222436388334,
#    'test_confidence': 0.004540042713499256},
#   {'epoch': 79,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.7917267262935639,
#    'val_loss': 0.9148000067472458,
#    'val_accuracy': 0.8737555767099062,
#    'test_loss': 0.9400807891289393,
#    'test_accuracy': 0.8651333532730738,
#    'test_confidence': 0.004440509807422209},
#   {'epoch': 80,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.8235290110111236,
#    'val_loss': 0.9237438993652661,
#    'val_accuracy': 0.8720889104406039,
#    'test_loss': 0.9413910254836082,
#    'test_accuracy': 0.8686889106035233,
#    'test_confidence': 0.00453870298614903},
#   {'epoch': 81,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.9064213633537292,
#    'val_loss': 0.9226490968465805,
#    'val_accuracy': 0.8717777987321218,
#    'test_loss': 0.9442870434125265,
#    'test_accuracy': 0.8669111318389575,
#    'test_confidence': 0.004702949972240655},
#   {'epoch': 82,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.8495576202869415,
#    'val_loss': 0.9206036525964737,
#    'val_accuracy': 0.8705333558718363,
#    'test_loss': 0.9483707619706789,
#    'test_accuracy': 0.8631777987877528,
#    'test_confidence': 0.0046685688102723055},
#   {'epoch': 83,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.8270265102386475,
#    'val_loss': 0.918665760755539,
#    'val_accuracy': 0.8729111329714457,
#    'test_loss': 0.9386126501361529,
#    'test_accuracy': 0.8662444657087326,
#    'test_confidence': 0.004549451419374264},
#   {'epoch': 84,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.7852431774139405,
#    'val_loss': 0.9187484391530355,
#    'val_accuracy': 0.8704000201821327,
#    'test_loss': 0.9383564785122871,
#    'test_accuracy': 0.8684666870037715,
#    'test_confidence': 0.0044441601607463155},
#   {'epoch': 85,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.878401780128479,
#    'val_loss': 0.9186532188455264,
#    'val_accuracy': 0.8775555765628815,
#    'test_loss': 0.9437863581379254,
#    'test_accuracy': 0.8646666877468427,
#    'test_confidence': 0.004814745064189514},
#   {'epoch': 86,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.8199123799800873,
#    'val_loss': 0.9210778568188349,
#    'val_accuracy': 0.8749778003493944,
#    'test_loss': 0.9429321478803953,
#    'test_accuracy': 0.8662444651126862,
#    'test_confidence': 0.004452381048637109},
#   {'epoch': 87,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.7728360950946808,
#    'val_loss': 0.924991376598676,
#    'val_accuracy': 0.8734000211954117,
#    'test_loss': 0.9432557321588199,
#    'test_accuracy': 0.866066688199838,
#    'test_confidence': 0.004527041247367113},
#   {'epoch': 88,
#    'current_lr_0': 5e-05,
#    'train_loss': 0.7761459171772003,
#    'val_loss': 0.9223592851559321,
#    'val_accuracy': 0.8737555769085884,
#    'test_loss': 0.9436345209678014,
#    'test_accuracy': 0.8658666876951854,
#    'test_confidence': 0.004634509334518148},
#   {'epoch': 89,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8021426439285279,
#    'val_loss': 0.918684289654096,
#    'val_accuracy': 0.8786666883031528,
#    'test_loss': 0.9465698540210724,
#    'test_accuracy': 0.8664000203212102,
#    'test_confidence': 0.004570238364207829},
#   {'epoch': 90,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.831124746799469,
#    'val_loss': 0.9212536651889484,
#    'val_accuracy': 0.8778666893641154,
#    'test_loss': 0.9423596988121669,
#    'test_accuracy': 0.8673777988553047,
#    'test_confidence': 0.00446989292491642},
#   {'epoch': 91,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.824679034948349,
#    'val_loss': 0.9264528647065162,
#    'val_accuracy': 0.8691111326217651,
#    'test_loss': 0.9443478931983312,
#    'test_accuracy': 0.8651333531737327,
#    'test_confidence': 0.004516340760758358},
#   {'epoch': 92,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8303895115852356,
#    'val_loss': 0.9229387519756953,
#    'val_accuracy': 0.8717333554228147,
#    'test_loss': 0.944943307240804,
#    'test_accuracy': 0.8698222428560257,
#    'test_confidence': 0.004705706882193113},
#   {'epoch': 93,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8421092927455902,
#    'val_loss': 0.9216398841142655,
#    'val_accuracy': 0.8741333556175231,
#    'test_loss': 0.9412414210041364,
#    'test_accuracy': 0.8649555775523186,
#    'test_confidence': 0.004796605586430947},
#   {'epoch': 94,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8294003188610077,
#    'val_loss': 0.9176316171884537,
#    'val_accuracy': 0.8744889107346535,
#    'test_loss': 0.9391997054219245,
#    'test_accuracy': 0.869066688021024,
#    'test_confidence': 0.004689088157687778},
#   {'epoch': 95,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8401763498783111,
#    'val_loss': 0.9177141055464745,
#    'val_accuracy': 0.872000020245711,
#    'test_loss': 0.9425786004463832,
#    'test_accuracy': 0.8642000202337901,
#    'test_confidence': 0.004611941157898316},
#   {'epoch': 96,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8383089959621429,
#    'val_loss': 0.9257192199428876,
#    'val_accuracy': 0.8680000212788582,
#    'test_loss': 0.9373999336361885,
#    'test_accuracy': 0.8660444642106692,
#    'test_confidence': 0.004602049377438412},
#   {'epoch': 97,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8170564770698547,
#    'val_loss': 0.9179521577556928,
#    'val_accuracy': 0.8730444660782815,
#    'test_loss': 0.9352377224961916,
#    'test_accuracy': 0.870311131576697,
#    'test_confidence': 0.004598831172332854},
#   {'epoch': 98,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8350756227970123,
#    'val_loss': 0.9235006668170294,
#    'val_accuracy': 0.8706000208854675,
#    'test_loss': 0.9415010022123654,
#    'test_accuracy': 0.8666666872302691,
#    'test_confidence': 0.004645233210512487},
#   {'epoch': 99,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.8045966565608978,
#    'val_loss': 0.9221150614817937,
#    'val_accuracy': 0.8732000208894412,
#    'test_loss': 0.9425189075867335,
#    'test_accuracy': 0.8627777992685636,
#    'test_confidence': 0.00475000846302252},
#   {'epoch': 100,
#    'current_lr_0': 5e-06,
#    'train_loss': 0.7921049892902374,
#    'val_loss': 0.923102918167909,
#    'val_accuracy': 0.8746666886409123,
#    'test_loss': 0.9376202388604482,
#    'test_accuracy': 0.8686666888991992,
#    'test_confidence': 0.004503106411886582}],
#  [{'epoch': 0,
#    'current_lr_0': 0.005,
#    'train_loss': 1.09592644572258,
#    'val_loss': 0.9553097054362297,
#    'val_accuracy': 0.828222242196401,
#    'test_loss': 0.983940461675326,
#    'test_accuracy': 0.8147777972618738,
#    'test_confidence': 0.005894602768399768},
#   {'epoch': 1,
#    'current_lr_0': 0.005,
#    'train_loss': 0.9605265378952026,
#    'val_loss': 0.9645868633190791,
#    'val_accuracy': 0.8275111311674118,
#    'test_loss': 0.9872027811408043,
#    'test_accuracy': 0.8218222416440646,
#    'test_confidence': 0.005601661093593855},
#   {'epoch': 2,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0640574157238007,
#    'val_loss': 0.9655452178915341,
#    'val_accuracy': 0.8280444646875064,
#    'test_loss': 0.9944857136408488,
#    'test_accuracy': 0.820333351790905,
#    'test_confidence': 0.005417934970078236},
#   {'epoch': 3,
#    'current_lr_0': 0.005,
#    'train_loss': 1.113589197397232,
#    'val_loss': 0.9674880344669025,
#    'val_accuracy': 0.8283333522081375,
#    'test_loss': 0.9925799443324407,
#    'test_accuracy': 0.8120444630583127,
#    'test_confidence': 0.005517515745582364},
#   {'epoch': 4,
#    'current_lr_0': 0.005,
#    'train_loss': 1.122366613149643,
#    'val_loss': 0.9731467448671659,
#    'val_accuracy': 0.8256666864951452,
#    'test_loss': 0.9954814818501473,
#    'test_accuracy': 0.8085111294190089,
#    'test_confidence': 0.005919240579839415},
#   {'epoch': 5,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0765580594539643,
#    'val_loss': 0.9698839730024338,
#    'val_accuracy': 0.8215111295382181,
#    'test_loss': 0.9992393283049266,
#    'test_accuracy': 0.8112444637219111,
#    'test_confidence': 0.005804142059297898},
#   {'epoch': 6,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0033296585083007,
#    'val_loss': 0.9751636319359144,
#    'val_accuracy': 0.8249777973691622,
#    'test_loss': 1.0043898806969325,
#    'test_accuracy': 0.8139333513379097,
#    'test_confidence': 0.005476454955037455},
#   {'epoch': 7,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1765387594699859,
#    'val_loss': 0.951801752547423,
#    'val_accuracy': 0.8308444647987684,
#    'test_loss': 0.9838053441047668,
#    'test_accuracy': 0.8217555751403173,
#    'test_confidence': 0.005609966206725151},
#   {'epoch': 8,
#    'current_lr_0': 0.005,
#    'train_loss': 1.1019440472126008,
#    'val_loss': 0.9542610962192217,
#    'val_accuracy': 0.8325555743773778,
#    'test_loss': 0.9787194720904032,
#    'test_accuracy': 0.8243555751442909,
#    'test_confidence': 0.005792741174094536},
#   {'epoch': 9,
#    'current_lr_0': 0.005,
#    'train_loss': 1.0888914942741394,
#    'val_loss': 0.9597494821747145,
#    'val_accuracy': 0.8208889074126879,
# ...
#    'test_accuracy': 0.6178000142673651,
#    'test_confidence': 0.008438560177086373},
#   {'epoch': 37,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.421615517139435,
#    'val_loss': 1.2083760331074396,
#    'val_accuracy': 0.6322889035443465,
#    'test_loss': 1.2224306864539782,
#    'test_accuracy': 0.6202889024714628,
#    'test_confidence': 0.00864649544923985},
#   {'epoch': 38,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.290597176551819,
#    'val_loss': 1.2150284620126088,
#    'val_accuracy': 0.6260889035463333,
#    'test_loss': 1.2195900305112204,
#    'test_accuracy': 0.6237555685142676,
#    'test_confidence': 0.008714704125273216},
#   {'epoch': 39,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.3211751937866212,
#    'val_loss': 1.213047050734361,
#    'val_accuracy': 0.6247777911027272,
#    'test_loss': 1.2188518970211346,
#    'test_accuracy': 0.6197555682063103,
#    'test_confidence': 0.008255258955451728},
#   {'epoch': 40,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.307846450805664,
#    'val_loss': 1.2174749371409417,
#    'val_accuracy': 0.6247333470980326,
#    'test_loss': 1.2185818553964296,
#    'test_accuracy': 0.6130444590250651,
#    'test_confidence': 0.007991139793589435},
#   {'epoch': 41,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.3374406099319458,
#    'val_loss': 1.2194391301274299,
#    'val_accuracy': 0.6226666805148124,
#    'test_loss': 1.2244933910171192,
#    'test_accuracy': 0.6146000131964684,
#    'test_confidence': 0.008222118842640434},
#   {'epoch': 42,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.4361135363578796,
#    'val_loss': 1.2229320754607518,
#    'val_accuracy': 0.6158444586892923,
#    'test_loss': 1.223267284532388,
#    'test_accuracy': 0.6166444595654805,
#    'test_confidence': 0.008231211621856815},
#   {'epoch': 43,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.3870609521865844,
#    'val_loss': 1.2158417532841364,
#    'val_accuracy': 0.630044459104538,
#    'test_loss': 1.22549213518699,
#    'test_accuracy': 0.6187777910133203,
#    'test_confidence': 0.008669989647429006},
#   {'epoch': 44,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.330789291858673,
#    'val_loss': 1.2157286737362545,
#    'val_accuracy': 0.6220889025429884,
#    'test_loss': 1.218084855278333,
#    'test_accuracy': 0.6234444580475489,
#    'test_confidence': 0.008423205139692715},
#   {'epoch': 45,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.2912623643875123,
#    'val_loss': 1.22143194069465,
#    'val_accuracy': 0.6225111251076062,
#    'test_loss': 1.2269459036986032,
#    'test_accuracy': 0.6148444589475791,
#    'test_confidence': 0.008851111395259813},
#   {'epoch': 46,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.4582971692085267,
#    'val_loss': 1.2185575300455094,
#    'val_accuracy': 0.6216444584727288,
#    'test_loss': 1.2167943294843038,
#    'test_accuracy': 0.6211111255238454,
#    'test_confidence': 0.008334615149574835},
#   {'epoch': 47,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.439626145362854,
#    'val_loss': 1.210660767753919,
#    'val_accuracy': 0.6296000137428442,
#    'test_loss': 1.2284264265497526,
#    'test_accuracy': 0.6156889013946056,
#    'test_confidence': 0.008622582655159278},
#   {'epoch': 48,
#    'current_lr_0': 0.0005,
#    'train_loss': 1.4116411685943604,
#    'val_loss': 1.212313356101513,
#    'val_accuracy': 0.6295111252367497,
#    'test_loss': 1.2214791014790536,
#    'test_accuracy': 0.6176666812102,
#    'test_confidence': 0.008398214921758095},
#   {'epoch': 49,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.25303373336792,
#    'val_loss': 1.2104997056722642,
#    'val_accuracy': 0.6369333476821581,
#    'test_loss': 1.2198394318421681,
#    'test_accuracy': 0.6183333464463552,
#    'test_confidence': 0.008401054159582975},
#   {'epoch': 50,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.3762197017669677,
#    'val_loss': 1.2180636562903722,
#    'val_accuracy': 0.6299777912596861,
#    'test_loss': 1.211921461323897,
#    'test_accuracy': 0.631311125655969,
#    'test_confidence': 0.008617151643509782},
#   {'epoch': 51,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.3047506213188171,
#    'val_loss': 1.2139466559886933,
#    'val_accuracy': 0.629422237376372,
#    'test_loss': 1.2192381165424984,
#    'test_accuracy': 0.6184889025986194,
#    'test_confidence': 0.008177294626900549},
#   {'epoch': 52,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.3632902145385741,
#    'val_loss': 1.2241503692666689,
#    'val_accuracy': 0.6209555699427922,
#    'test_loss': 1.2276564832528432,
#    'test_accuracy': 0.6159333457052708,
#    'test_confidence': 0.008388276853232493},
#   {'epoch': 53,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.331126368045807,
#    'val_loss': 1.218434957563877,
#    'val_accuracy': 0.6215777911742528,
#    'test_loss': 1.2257484449942906,
#    'test_accuracy': 0.6181111248830954,
#    'test_confidence': 0.008677578286541027},
#   {'epoch': 54,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.3009787678718567,
#    'val_loss': 1.2175601810216903,
#    'val_accuracy': 0.6251777916649978,
#    'test_loss': 1.219732334713141,
#    'test_accuracy': 0.6199333463112513,
#    'test_confidence': 0.008204278727463873},
#   {'epoch': 55,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.41283038854599,
#    'val_loss': 1.222983000675837,
#    'val_accuracy': 0.61966668009758,
#    'test_loss': 1.2232804081837336,
#    'test_accuracy': 0.6183777909477551,
#    'test_confidence': 0.00852129443640099},
#   {'epoch': 56,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.4981165885925294,
#    'val_loss': 1.2203288383285205,
#    'val_accuracy': 0.6209777896106243,
#    'test_loss': 1.2285790223876636,
#    'test_accuracy': 0.6112222349643708,
#    'test_confidence': 0.008547320611039917},
#   {'epoch': 57,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.3311457991600038,
#    'val_loss': 1.220300063987573,
#    'val_accuracy': 0.6206222354620695,
#    'test_loss': 1.225557956000169,
#    'test_accuracy': 0.6149555685619513,
#    'test_confidence': 0.008449230942037214},
#   {'epoch': 58,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.3193450450897217,
#    'val_loss': 1.2212223091721535,
#    'val_accuracy': 0.624800013701121,
#    'test_loss': 1.2204166439175606,
#    'test_accuracy': 0.6210222349067529,
#    'test_confidence': 0.008654077615266775},
#   {'epoch': 59,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.304729127883911,
#    'val_loss': 1.2241244543592136,
#    'val_accuracy': 0.6257555698851744,
#    'test_loss': 1.2268415665626526,
#    'test_accuracy': 0.6092000139256318,
#    'test_confidence': 0.00845196522002269},
#   {'epoch': 60,
#    'current_lr_0': 5e-05,
#    'train_loss': 1.4210963129997254,
#    'val_loss': 1.216518587867419,
#    'val_accuracy': 0.6270889023443064,
#    'test_loss': 1.2191386623183886,
#    'test_accuracy': 0.6205111248294513,
#    'test_confidence': 0.008324913539430108},
#   {'epoch': 61,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.355292809009552,
#    'val_loss': 1.2061622934540113,
#    'val_accuracy': 0.6355555692811807,
#    'test_loss': 1.219159764945507,
#    'test_accuracy': 0.6266222356756528,
#    'test_confidence': 0.008378013689804256},
#   {'epoch': 62,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.3516546964645386,
#    'val_loss': 1.2186877998709678,
#    'val_accuracy': 0.6259111250936985,
#    'test_loss': 1.2271556532382966,
#    'test_accuracy': 0.6146000137428442,
#    'test_confidence': 0.008568235572404102},
#   {'epoch': 63,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.40691579580307,
#    'val_loss': 1.211444777548313,
#    'val_accuracy': 0.6238000130653382,
#    'test_loss': 1.2256572725375494,
#    'test_accuracy': 0.6134444579482079,
#    'test_confidence': 0.008001428045939394},
#   {'epoch': 64,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.337723469734192,
#    'val_loss': 1.2146801992257437,
#    'val_accuracy': 0.6254444595177968,
#    'test_loss': 1.2185042795538903,
#    'test_accuracy': 0.6221111250420411,
#    'test_confidence': 0.008282849253605938},
#   {'epoch': 65,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.31224445104599,
#    'val_loss': 1.2181603892644246,
#    'val_accuracy': 0.6226000136137009,
#    'test_loss': 1.2270763981342316,
#    'test_accuracy': 0.6154222360750039,
#    'test_confidence': 0.008306806520515728},
#   {'epoch': 66,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.3594040870666504,
#    'val_loss': 1.219040359556675,
#    'val_accuracy': 0.6260000142703454,
#    'test_loss': 1.2300947138667107,
#    'test_accuracy': 0.6127111251652241,
#    'test_confidence': 0.008292257381739701},
#   {'epoch': 67,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.3340059638023376,
#    'val_loss': 1.2249500814080239,
#    'val_accuracy': 0.6236222366988659,
#    'test_loss': 1.2242904545863469,
#    'test_accuracy': 0.6140222363670667,
#    'test_confidence': 0.008536760535764932},
#   {'epoch': 68,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.3551020622253418,
#    'val_loss': 1.213122707903385,
#    'val_accuracy': 0.6295777916908264,
#    'test_loss': 1.2170611241459846,
#    'test_accuracy': 0.6275555682679017,
#    'test_confidence': 0.008433999556803158},
#   {'epoch': 69,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.345851230621338,
#    'val_loss': 1.2156791642308236,
#    'val_accuracy': 0.6286889031529427,
#    'test_loss': 1.2208002664645512,
#    'test_accuracy': 0.6222444583972295,
#    'test_confidence': 0.008525086356944834},
#   {'epoch': 70,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.3903327226638793,
#    'val_loss': 1.2168007523814837,
#    'val_accuracy': 0.6279555692772071,
#    'test_loss': 1.216971988081932,
#    'test_accuracy': 0.620977790604035,
#    'test_confidence': 0.008467800576778334},
#   {'epoch': 71,
#    'current_lr_0': 5e-06,
#    'train_loss': 1.2362438559532165,
#    'val_loss': 1.2114854643742243,
#    'val_accuracy': 0.6274889024595419,
#    'test_loss': 1.2163716001311937,
#    'test_accuracy': 0.6269333462913831,
#    'test_confidence': 0.008457541315292806},
#   {'epoch': 72,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.3353513598442077,
#    'val_loss': 1.2159323474764825,
#    'val_accuracy': 0.6253111243247986,
#    'test_loss': 1.221198404530684,
#    'test_accuracy': 0.6196889022489389,
#    'test_confidence': 0.007985521755669868},
#   {'epoch': 73,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.3918219089508057,
#    'val_loss': 1.2168357425928116,
#    'val_accuracy': 0.6275555693606536,
#    'test_loss': 1.2301683442791302,
#    'test_accuracy': 0.6110444567104181,
#    'test_confidence': 0.008234145428992215},
#   {'epoch': 74,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.262174141407013,
#    'val_loss': 1.2216508886218072,
#    'val_accuracy': 0.6202666816612085,
#    'test_loss': 1.2230305246512094,
#    'test_accuracy': 0.6180000127355257,
#    'test_confidence': 0.007696309629774512},
#   {'epoch': 75,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.3997673511505127,
#    'val_loss': 1.2181679785251618,
#    'val_accuracy': 0.6256000122924645,
#    'test_loss': 1.2195887940128645,
#    'test_accuracy': 0.6207555693884691,
#    'test_confidence': 0.008366400690702748},
#   {'epoch': 76,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.3429931044578551,
#    'val_loss': 1.2118571636080742,
#    'val_accuracy': 0.6338444584111372,
#    'test_loss': 1.2247807183861732,
#    'test_accuracy': 0.6210000137984752,
#    'test_confidence': 0.008346143435298534},
#   {'epoch': 77,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.364693820476532,
#    'val_loss': 1.2230275166034699,
#    'val_accuracy': 0.6211333467562994,
#    'test_loss': 1.2194146483143171,
#    'test_accuracy': 0.6203555687268575,
#    'test_confidence': 0.008460001250784069},
#   {'epoch': 78,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.2809117674827575,
#    'val_loss': 1.2126900893449784,
#    'val_accuracy': 0.6277333487073581,
#    'test_loss': 1.2247347978750864,
#    'test_accuracy': 0.6142666804790496,
#    'test_confidence': 0.00811320460513105},
#   {'epoch': 79,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.4362855553627014,
#    'val_loss': 1.221405934592088,
#    'val_accuracy': 0.6272222369412581,
#    'test_loss': 1.220848167737325,
#    'test_accuracy': 0.6205777921527624,
#    'test_confidence': 0.008387672788879754},
#   {'epoch': 80,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.4520720720291138,
#    'val_loss': 1.2120140289266905,
#    'val_accuracy': 0.6292000137021144,
#    'test_loss': 1.2197700202465058,
#    'test_accuracy': 0.6220000135401885,
#    'test_confidence': 0.008155123661420021},
#   {'epoch': 81,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.3273064136505126,
#    'val_loss': 1.2144084068139394,
#    'val_accuracy': 0.6279555694262187,
#    'test_loss': 1.2235813261071842,
#    'test_accuracy': 0.6171333470443885,
#    'test_confidence': 0.00831770802607926},
#   {'epoch': 82,
#    'current_lr_0': 5.000000000000001e-07,
#    'train_loss': 1.3810343146324158,
#    'val_loss': 1.2193724007407825,
#    'val_accuracy': 0.6236444576084614,
#    'test_loss': 1.2259627058108649,
#    'test_accuracy': 0.616600013722976,
#    'test_confidence': 0.00828077901340559},
#   {'epoch': 83,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.335750687122345,
#    'val_loss': 1.2151509563128153,
#    'val_accuracy': 0.6292444591224193,
#    'test_loss': 1.2230012108882269,
#    'test_accuracy': 0.622600013713042,
#    'test_confidence': 0.008477304737138166},
#   {'epoch': 84,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.2761333465576172,
#    'val_loss': 1.2148680222034454,
#    'val_accuracy': 0.6282222370803356,
#    'test_loss': 1.2257732171813647,
#    'test_accuracy': 0.6185777904589971,
#    'test_confidence': 0.008757593292127056},
#   {'epoch': 85,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.4350814342498779,
#    'val_loss': 1.2179503893852235,
#    'val_accuracy': 0.6266444577773412,
#    'test_loss': 1.2171516993641853,
#    'test_accuracy': 0.6226889017224312,
#    'test_confidence': 0.008511715257064435},
#   {'epoch': 86,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.314078140258789,
#    'val_loss': 1.212683100104332,
#    'val_accuracy': 0.6278222365677357,
#    'test_loss': 1.2193109016617139,
#    'test_accuracy': 0.6242889028290908,
#    'test_confidence': 0.007673894298113064},
#   {'epoch': 87,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.3643173336982728,
#    'val_loss': 1.2143082938591638,
#    'val_accuracy': 0.6278666800012191,
#    'test_loss': 1.2155808836221695,
#    'test_accuracy': 0.620422234882911,
#    'test_confidence': 0.00868235245409608},
#   {'epoch': 88,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.3182262420654296,
#    'val_loss': 1.2138780985275905,
#    'val_accuracy': 0.6277111239731312,
#    'test_loss': 1.221473141113917,
#    'test_accuracy': 0.6192666804293792,
#    'test_confidence': 0.008874134091452848},
#   {'epoch': 89,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.3941930770874023,
#    'val_loss': 1.215402434070905,
#    'val_accuracy': 0.627755569194754,
#    'test_loss': 1.2184050713976224,
#    'test_accuracy': 0.6233111255367597,
#    'test_confidence': 0.00856727957281712},
#   {'epoch': 90,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.408981728553772,
#    'val_loss': 1.2120047572255135,
#    'val_accuracy': 0.6330666798353195,
#    'test_loss': 1.2222956674297651,
#    'test_accuracy': 0.6182444584866365,
#    'test_confidence': 0.008116089259229797},
#   {'epoch': 91,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.4249237537384034,
#    'val_loss': 1.2176181531945864,
#    'val_accuracy': 0.6301555689175924,
#    'test_loss': 1.2189096369345982,
#    'test_accuracy': 0.6198000148683787,
#    'test_confidence': 0.008672289708236547},
#   {'epoch': 92,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.3182183265686036,
#    'val_loss': 1.2105724541346232,
#    'val_accuracy': 0.6303555678824584,
#    'test_loss': 1.222923860947291,
#    'test_accuracy': 0.6200666805605094,
#    'test_confidence': 0.00824741919750477},
#   {'epoch': 93,
#    'current_lr_0': 5.000000000000001e-08,
#    'train_loss': 1.3695074200630188,
#    'val_loss': 1.2186787524819374,
#    'val_accuracy': 0.6261555698513984,
#    'test_loss': 1.22651993393898,
#    'test_accuracy': 0.6162000132103761,
#    'test_confidence': 0.00847866392859172}]]
