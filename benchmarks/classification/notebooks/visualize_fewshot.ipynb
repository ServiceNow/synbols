# %%
# %matplotlib notebook
# Specify variables
# sys.path.insert(local_haven)
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as hu

# please define the path to the experiments
# savedir_base = '/mnt/projects/vision_prototypes/synbols/white_noise_borgy/'
savedir_base = '/mnt/projects/vision_prototypes/synbols/logs_borgy_baselines/'
# savedir_base = '/mnt/projects/vision_prototypes/synbols/font_plain_borgy/'

exp_list = None

# exp_config_name = <exp_config_name>
# exp_list = hu.load_py(exp_config_name).EXP_GROUPS['mnist']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None

# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
# y_metrics='train_loss'
x_metric='epoch'
# log_metric_list = ['train_loss']
map_exp_list = []
# title_list=['dataset']
# legend_list=['model']

# get experiments
rm = hr.ResultManager(exp_list=exp_list, 
                      savedir_base=savedir_base, 
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
score_lists = rm.get_score_lists()
# score = rm.get_score_table(columns=['dataset', 'exp_id'])


# launch dashboard
hj.get_dashboard(rm, vars(), wide_display=True)
# Out:
# 100%|██████████| 1288/1288 [00:01<00:00, 679.15it/s]
# VBox(children=(Label(value='Select exp_group', layout=Layout(width='200px')), HBox(children=(Dropdown(layout=L…
# Output()
# <style>.container { width:100% !important; }</style>
#         <style>
#             .output_scroll {
#                 height: unset !important;
#                 border-radius: unset !important;
#                 -webkit-box-shadow: unset !important;
#                 box-shadow: unset !important;
#             }
#         </style>

# %%
import numpy as np

exp_list = rm.get_exp_list_df()

def get_hyperparameters(exp_list_df, min_threshold=2, max_threshold=None):
    exp_list_df.reset_index()
    if max_threshold is None:
        max_threshold = exp_list.shape[0] - 1
    column_count = []
    for column in exp_list.columns:
        _set = set([str(v) for v in exp_list[column].values])
        column_count.append(len(_set))
    indices = np.arange(len(exp_list.columns))
    column_count = np.array(column_count)
    indices = indices[(column_count >= min_threshold) & (column_count <= max_threshold)]
    hyperparameters = [exp_list.columns[i] for i in indices]
    return hyperparameters

# %%
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

def multipage(filename, figs=None, dpi=200):
    pp = PdfPages(filename)
    if figs is None:
        figs = [plt.figure(n) for n in plt.get_fignums()]
    for fig in figs:
        fig.savefig(pp, format='pdf')
    pp.close()
multipage('synbols.pdf')

# %% [markdown]
# ## Show accuracies

# %%
import numpy as np
df = rm.get_score_df()
datasets = ["mnist", "svhn", "default_n=100000_","default_n=1000000_", "camouflage", "tiny",  "less_variations_n=100000_", "less_variations_n=1000000_"]
models = ["mlp", "conv4", "conv4_gap", "resnet18", "wrn", "vgg16", "warn"]
masks = ["'random'", "'stratified_font'", "'stratified_char'", "'compositional_char_font'", "'stratified_scale'", "'stratified_rotation'", "'compositional_rotation_scale'", "'stratified_translation-x'", "'stratified_translation-y'", "'compositional_translation-x_translation-y'"]
tasks = ["font", "char"]

def filter_dataset(dataframe, dset):
    if dataset in ["mnist", "svhn"]:
        df_dataset = dataframe[dataframe["dataset.name"].str.contains(dset)]
    else:
        df_dataset = dataframe[dataframe["dataset.path"].str.contains(dset)]
    return df_dataset
def filter_task(dataframe, task):
    if dataset not in ["mnist", "svhn"]:
        df_dataset = dataframe[dataframe["dataset.task"].str.contains(task)]
    else:
        df_dataset = dataframe
    return df_dataset 
def filter_mask(dataframe, mask):
    df_ood = dataframe[dataframe['dataset.mask'] == mask]
    return df_ood


for dataset in datasets:
    #     df_model = df[df["backbone.name"].str.contains(model)]
    df_dataset = filter_dataset(df, dataset)
    for task in tasks:
        df_task = filter_task(df_dataset, task)
        for mask in masks:

            if dataset not in ["mnist", "svhn"]:
                df_ood = filter_mask(df_task, mask)
            else:
                df_ood = df_task
                if task != "char" or mask != "'random'":
                    continue
            if len(df_ood) == 0:
                continue
            print("Dset:%s, Task:%s, MASK:%s"% (dataset, task, mask))
            print(','.join(models))
            for model in models:
                if "conv4" in model:
                    df_model = df_ood[df_ood["backbone.name"].str.contains("conv4")]
                    if 'True' in list(df_model["backbone.gap"].values) or 'False' in list(df_model["backbone.gap"].values):
                        if "gap" in model:       
                            df_model = df_model[df_model["backbone.gap"].str.contains('True')]
                        else:
                            df_model = df_model[df_model["backbone.gap"].str.contains('False')]
                    else:
                        if "gap" in model:
                            print("N/A")
                            continue
                else:
                    df_model = df_ood[df_ood["backbone.name"].str.contains(model)]
                df_model = df_model.groupby('seed')["val_accuracy (max)"].agg(np.nanmax).reset_index()
                print("%.02f ±%.02f" %(100*df_model["val_accuracy (max)"].agg(np.nanmean), 100*df_model["val_accuracy (max)"].agg(np.nanstd)))#, df_model["val_accuracy (max)"].std())
# Out:
# Dset:mnist, Task:char, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 98.54 ±0.08
# 99.41 ±0.03
# N/A
# 99.54 ±0.06
# 99.65 ±0.01
# 99.62 ±0.07
# 99.64 ±0.06
# Dset:svhn, Task:char, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 85.63 ±0.15
# 91.46 ±0.19
# N/A
# 93.75 ±0.04
# 96.16 ±0.04
# 95.74 ±0.21
# 96.42 ±0.10
# Dset:default_n=100000_, Task:font, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 0.17 ±0.01
# 4.80 ±0.61
# N/A
# 3.79 ±0.36
# nan ±nan
# 1.33 ±0.18
# 13.99 ±2.77
# Dset:default_n=100000_, Task:font, MASK:'stratified_char'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 0.21 ±0.04
# 4.90 ±0.24
# N/A
# 3.76 ±0.28
# nan ±nan
# 1.35 ±0.15
# 9.80 ±1.20
# Dset:default_n=100000_, Task:char, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 23.79 ±0.33
# 71.53 ±0.91
# N/A
# 74.34 ±0.33
# 80.86 ±0.43
# 79.87 ±0.17
# 80.06 ±0.52
# Dset:default_n=100000_, Task:char, MASK:'stratified_font'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 59.27 ±1.44
# 84.36 ±0.88
# 83.94 ±1.02
# 89.07 ±0.58
# 91.92 ±0.72
# 91.17 ±0.86
# 80.07 ±0.46
# Dset:default_n=100000_, Task:char, MASK:'compositional_char_font'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 15.52 ±0.05
# 62.41 ±0.36
# N/A
# 66.25 ±0.32
# nan ±nan
# 70.53 ±2.87
# 76.31 ±1.14
# Dset:default_n=100000_, Task:char, MASK:'stratified_scale'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 21.52 ±0.70
# 66.46 ±0.53
# 58.58 ±0.24
# 73.70 ±0.13
# 78.81 ±0.20
# 74.92 ±0.25
# 78.79 ±0.51
# Dset:default_n=100000_, Task:char, MASK:'stratified_rotation'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 13.81 ±0.11
# 46.69 ±0.50
# 44.63 ±0.28
# 60.31 ±0.48
# 69.41 ±0.74
# 65.89 ±0.69
# 77.00 ±0.94
# Dset:default_n=100000_, Task:char, MASK:'stratified_translation-x'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 12.89 ±0.24
# 44.70 ±0.82
# 58.84 ±0.55
# 65.77 ±0.46
# 80.41 ±0.67
# 76.48 ±0.29
# 80.54 ±0.35
# Dset:default_n=100000_, Task:char, MASK:'stratified_translation-y'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 15.07 ±0.18
# 48.79 ±0.66
# 59.61 ±0.37
# 66.93 ±0.34
# 80.73 ±0.09
# 76.98 ±0.29
# 80.36 ±0.21
# Dset:default_n=1000000_, Task:char, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 60.25 ±0.54
# 81.13 ±0.04
# N/A
# 84.75 ±0.07
# 87.33 ±0.06
# 85.36 ±0.91
# 87.17 ±0.17
# Dset:default_n=1000000_, Task:char, MASK:'compositional_char_font'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 20.22 ±0.23
# 62.63 ±0.78
# 63.46 ±0.44
# 72.86 ±0.65
# 80.25 ±0.31
# 78.38 ±0.99
# 0.00 ±0.00
# Dset:default_n=1000000_, Task:char, MASK:'compositional_rotation_scale'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 15.08 ±0.50
# 57.53 ±0.38
# 55.78 ±0.30
# 67.58 ±0.37
# 77.19 ±0.75
# 73.46 ±0.25
# 0.00 ±0.00
# Dset:default_n=1000000_, Task:char, MASK:'compositional_translation-x_translation-y'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 14.50 ±0.16
# 46.29 ±0.36
# 61.47 ±0.87
# 64.97 ±0.51
# 81.62 ±0.26
# 78.55 ±0.62
# 0.00 ±0.00
# Dset:camouflage, Task:char, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 2.10 ±0.02
# 27.64 ±0.76
# N/A
# 43.70 ±0.94
# 74.83 ±0.23
# 69.57 ±0.33
# 70.17 ±1.68
# Dset:tiny, Task:char, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 32.88 ±0.55
# 36.02 ±1.03
# nan ±nan
# nan ±nan
# nan ±nan
# nan ±nan
# nan ±nan
# Dset:less_variations_n=100000_, Task:font, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 0.18 ±0.03
# 0.64 ±0.11
# 5.45 ±0.32
# 5.80 ±0.28
# 33.83 ±3.76
# 3.12 ±1.47
# 23.67 ±5.59
# Dset:less_variations_n=100000_, Task:font, MASK:'stratified_char'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 14.99 ±4.47
# 59.77 ±9.80
# 59.64 ±10.49
# 61.22 ±9.39
# 65.54 ±8.05
# 59.97 ±9.85
# 15.66 ±0.60
# Dset:less_variations_n=1000000_, Task:font, MASK:'random'
# mlp,conv4,conv4_gap,resnet18,wrn,vgg16,warn
# 4.11 ±0.14
# 56.51 ±0.50
# N/A
# 75.40 ±0.96
# 88.73 ±0.16
# 62.37 ±6.37
# 88.79 ±0.80

# %% [markdown]
# ## Show times

# %%
df = rm.get_score_df()

datasets = ["plain", "default_n=1000000_", "default_n=100000_", "mnist", "svhn", "tiny"]
datasets = ["tiny"]
models = ["mlp", "conv4", "resnet18", "resnet50", "vgg16", "warn"]


for dataset in datasets:
#     df_model = df[df["backbone.name"].str.contains(model)]
    print(dataset)
    if dataset in ["mnist", "svhn"]:
        df_dataset = df[df["dataset.name"].str.contains(dataset)]
    else:
        df_dataset = df[df["dataset.path"].str.contains(dataset)]
    for model in models:
        df_model = df_dataset[df_dataset["backbone.name"].str.contains(model)]
        print(df_model["val_batch_time"].mean())

# %%
a = """Tyler Hayes; Christopher Kanan
Seyed Iman Mirzadeh; Mehrdad Farajtabar; Hassan Ghasemzadeh
Tyler Hayes; Christopher Kanan
Seyed Iman Mirzadeh; Mehrdad Farajtabar; Hassan Ghasemzadeh
Ayub, Ali; Wagner, Alan
Parshotam, Kishan; Kilickaya, Mert
Liu, Xialei; Wu, Chenshen; Menta, Mikel; Herranz, Luis; RADUCANU, BOGDAN; Bagdanov, Andy; Jui, Shangling; van de Weijer, Joost
Ahn, Hongjoon; Moon, Taesup
Jung, Sang Won; Ahn, Hongjoon; Cha, Sungmin; Moon, Taesup*
Roady, Ryne P*; Hayes, Tyler; Vaidya,  Hitesh; Kanan, Christopher
Wang, Zhengwei*; She, Qi; Chalasani, Tejo; Smolic, Aljosa
Murata, Kengo*; Toyota, Tetsuya; Ohara, Kouzou
Kuo, Nicholas I*; Harandi, Mehrtash; Fourrier, Nicolas; Ferarro, Gabriela; Walder, Christian; Suominen, Hanna
Patsiouras, Emmanouil*; Tefas, Anastasios; Pitas, Ioannis
Mi, Fei*; Kong, Lingjing; Lin, Tao; Yu, Kaicheng; Faltings, Boi
Ebrahimi, Sayna*; Meier, Franziska; Calandra, Roberto; Darrell, Trevor; Rohrbach, Marcus
Caccia, Massimo*
Kim, Jangho; Kim, Jeesoo; Kwak, Nojun*
Du, Xiaocong*; Li, Zheng; Seo, Jae-sun; Liu, Frank; Cao, Yu
Lomonaco, Vincenzo*; Maltoni, Davide; Pellegrini, Lorenzo
Lomonaco, Vincenzo*; Desai, Karan; Culurciello, Eugenio; Maltoni, Davide
Ramakrishnan, Kandan*; Panda, Rameswar; Fan, Quanfu; Henning, John; Oliva, Aude; Feris, Rogerio
Masarczyk, Wojciech*; Tautkute, Ivona
DOSHI, KEVAL*; Yilmaz, Yasin
Silver, Danny*; Mahfuz, Sazia"""
for line in a.split("\n"):
    authors = line.split(";")
    ret = []
    for author in authors:
        ret.append(" ".join(author.replace('*', '').split(",")))
    print(",".join(ret))
for line in a.split("\n"):
    authors = line.split(";")
    ret = []
    for author in authors:
        ret.append(" ".join(author.replace('*', '').split(",")))
    print(len(ret))
# Out:
# Tyler Hayes, Christopher Kanan
# Seyed Iman Mirzadeh, Mehrdad Farajtabar, Hassan Ghasemzadeh
# Tyler Hayes, Christopher Kanan
# Seyed Iman Mirzadeh, Mehrdad Farajtabar, Hassan Ghasemzadeh
# Ayub  Ali, Wagner  Alan
# Parshotam  Kishan, Kilickaya  Mert
# Liu  Xialei, Wu  Chenshen, Menta  Mikel, Herranz  Luis, RADUCANU  BOGDAN, Bagdanov  Andy, Jui  Shangling, van de Weijer  Joost
# Ahn  Hongjoon, Moon  Taesup
# Jung  Sang Won, Ahn  Hongjoon, Cha  Sungmin, Moon  Taesup
# Roady  Ryne P, Hayes  Tyler, Vaidya   Hitesh, Kanan  Christopher
# Wang  Zhengwei, She  Qi, Chalasani  Tejo, Smolic  Aljosa
# Murata  Kengo, Toyota  Tetsuya, Ohara  Kouzou
# Kuo  Nicholas I, Harandi  Mehrtash, Fourrier  Nicolas, Ferarro  Gabriela, Walder  Christian, Suominen  Hanna
# Patsiouras  Emmanouil, Tefas  Anastasios, Pitas  Ioannis
# Mi  Fei, Kong  Lingjing, Lin  Tao, Yu  Kaicheng, Faltings  Boi
# Ebrahimi  Sayna, Meier  Franziska, Calandra  Roberto, Darrell  Trevor, Rohrbach  Marcus
# Caccia  Massimo
# Kim  Jangho, Kim  Jeesoo, Kwak  Nojun
# Du  Xiaocong, Li  Zheng, Seo  Jae-sun, Liu  Frank, Cao  Yu
# Lomonaco  Vincenzo, Maltoni  Davide, Pellegrini  Lorenzo
# Lomonaco  Vincenzo, Desai  Karan, Culurciello  Eugenio, Maltoni  Davide
# Ramakrishnan  Kandan, Panda  Rameswar, Fan  Quanfu, Henning  John, Oliva  Aude, Feris  Rogerio
# Masarczyk  Wojciech, Tautkute  Ivona
# DOSHI  KEVAL, Yilmaz  Yasin
# Silver  Danny, Mahfuz  Sazia
# 2
# 3
# 2
# 3
# 2
# 2
# 8
# 2
# 4
# 4
# 4
# 3
# 6
# 3
# 5
# 5
# 1
# 3
# 5
# 3
# 4
# 6
# 2
# 2
# 2
