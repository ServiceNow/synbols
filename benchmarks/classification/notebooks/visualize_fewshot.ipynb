# %%
# Specify variables
# sys.path.insert(local_haven)
from haven import haven_jupyter as hj
from haven import haven_results as hr
from haven import haven_utils as hu

# please define the path to the experiments
savedir_base = '/mnt/projects/vision_prototypes/synbols/logs_borgy_baselines/'
# savedir_base = '/mnt/projects/vision_prototypes/synbols/font_plain_borgy/'

exp_list = None

# exp_config_name = <exp_config_name>
# exp_list = hu.load_py(exp_config_name).EXP_GROUPS['mnist']

# get specific experiments, for example, {'model':'resnet34'}
filterby_list = None

# group the experiments based on a hyperparameter, for example, ['dataset']
groupby_list = None
verbose = 0

# plot vars
# y_metrics='train_loss'
x_metric='epoch'
# log_metric_list = ['train_loss']
map_exp_list = []
# title_list=['dataset']
# legend_list=['model']

# get experiments
rm = hr.ResultManager(exp_list=exp_list, 
                      savedir_base=savedir_base, 
                      filterby_list=filterby_list,
                      verbose=verbose
                     )
score_lists = rm.get_score_lists()
# score = rm.get_score_table(columns=['dataset', 'exp_id'])


# launch dashboard
hj.get_dashboard(rm, vars(), wide_display=True)
# Out:
# 100%|██████████| 504/504 [00:01<00:00, 472.67it/s]
# VBox(children=(Label(value='Select exp_group', layout=Layout(width='200px')), HBox(children=(Dropdown(layout=L…
# Output()
# <style>.container { width:100% !important; }</style>
#         <style>
#             .output_scroll {
#                 height: unset !important;
#                 border-radius: unset !important;
#                 -webkit-box-shadow: unset !important;
#                 box-shadow: unset !important;
#             }
#         </style>

# %%
import numpy as np

exp_list = rm.get_exp_list_df()

def get_hyperparameters(exp_list_df, min_threshold=2, max_threshold=None):
    exp_list_df.reset_index()
    if max_threshold is None:
        max_threshold = exp_list.shape[0] - 1
    column_count = []
    for column in exp_list.columns:
        _set = set([str(v) for v in exp_list[column].values])
        column_count.append(len(_set))
    indices = np.arange(len(exp_list.columns))
    column_count = np.array(column_count)
    indices = indices[(column_count >= min_threshold) & (column_count <= max_threshold)]
    hyperparameters = [exp_list.columns[i] for i in indices]
    return hyperparameters

# %%
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

def multipage(filename, figs=None, dpi=200):
    pp = PdfPages(filename)
    if figs is None:
        figs = [plt.figure(n) for n in plt.get_fignums()]
    for fig in figs:
        fig.savefig(pp, format='pdf')
    pp.close()
multipage('synbols.pdf')

# %% [markdown]
# ## Show accuracies

# %%
df = rm.get_score_df()
datasets = ["plain", "default_n=1000000_", "default_n=100000_", "mnist", "svhn", "camouflage", "tiny"]
models = ["mlp", "conv4", "resnet18", "resnet50", "vgg16", "warn"]
masks = ["'random'", "'stratified_font'", "'stratified_char'", "'compositional_char_font'"]
tasks = ["font", "char"]

def filter_dataset(dataframe, dset):
    if dataset in ["mnist", "svhn"]:
        df_dataset = dataframe[dataframe["dataset.name"].str.contains(dset)]
    else:
        df_dataset = dataframe[dataframe["dataset.path"].str.contains(dset)]
    return df_dataset
def filter_task(dataframe, task):
    if dataset not in ["mnist", "svhn"]:
        df_dataset = dataframe[dataframe["dataset.task"].str.contains(task)]
    else:
        df_dataset = dataframe
    return df_dataset 
def filter_mask(dataframe, mask):
    df_ood = dataframe[dataframe['dataset.mask'] == mask]
    return df_ood


for dataset in datasets:
    #     df_model = df[df["backbone.name"].str.contains(model)]
    df_dataset = filter_dataset(df, dataset)
    for task in tasks:
        df_task = filter_task(df_dataset, task)
        for mask in masks:
            print("Dset:%s, Task:%s, MASK:%s"% (dataset, task, mask))
            if dataset not in ["mnist", "svhn"]:
                df_ood = filter_mask(df_task, mask)
            else:
                df_ood = df_task
            for model in models:
                df_model = df_ood[df_ood["backbone.name"].str.contains(model)]
                df_model = df_model.groupby('seed')["val_accuracy (max)"].agg('max').reset_index()
                print(df_model["val_accuracy (max)"].mean())#, df_model["val_accuracy (max)"].std())
# Out:
# Dset:plain, Task:font, MASK:'random'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:font, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:font, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:font, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:char, MASK:'random'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:char, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:char, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:plain, Task:char, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:font, MASK:'random'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:font, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:font, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:font, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:char, MASK:'random'
# 0.60254
# 0.8113266666666666
# 0.8475400000000001
# 0.8558883333333333
# 0.8536183333333334
# 0.8810633333333332
# Dset:default_n=1000000_, Task:char, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:char, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=1000000_, Task:char, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=100000_, Task:font, MASK:'random'
# 0.0017499999999999998
# 0.04798333333333333
# 0.03791666666666666
# 0.007766666666666667
# 0.013266666666666668
# 0.1399
# Dset:default_n=100000_, Task:font, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=100000_, Task:font, MASK:'stratified_char'
# 0.002063225625961673
# 0.048957896209260034
# 0.037627640229402716
# 0.011679955238494895
# 0.013498391383410267
# 0.09803818715904322
# Dset:default_n=100000_, Task:font, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=100000_, Task:char, MASK:'random'
# 0.23788333333333334
# 0.7153
# 0.74345
# 0.7410833333333334
# 0.7987166666666666
# 0.82735
# Dset:default_n=100000_, Task:char, MASK:'stratified_font'
# 0.24003085488144346
# 0.7187175101452192
# 0.7355703122379852
# 0.7409028406613677
# 0.7853405775228897
# 0.8234564174799611
# Dset:default_n=100000_, Task:char, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:default_n=100000_, Task:char, MASK:'compositional_char_font'
# 0.15517344533390767
# 0.6241040552344713
# 0.6625025427480824
# 0.6371588230366994
# 0.7052685740268755
# 0.7630517763338958
# Dset:mnist, Task:font, MASK:'random'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:font, MASK:'stratified_font'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:font, MASK:'stratified_char'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:font, MASK:'compositional_char_font'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:char, MASK:'random'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:char, MASK:'stratified_font'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:char, MASK:'stratified_char'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:mnist, Task:char, MASK:'compositional_char_font'
# 0.9853666666666667
# 0.9941333333333334
# 0.9953666666666666
# 0.9941
# 0.9962
# 0.9971
# Dset:svhn, Task:font, MASK:'random'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:font, MASK:'stratified_font'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:font, MASK:'stratified_char'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:font, MASK:'compositional_char_font'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:char, MASK:'random'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:char, MASK:'stratified_font'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:char, MASK:'stratified_char'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:svhn, Task:char, MASK:'compositional_char_font'
# 0.8563050604384347
# 0.9145922966605203
# 0.9374871952468756
# 0.938678037287441
# 0.9574241958615038
# 0.9672966605203852
# Dset:camouflage, Task:font, MASK:'random'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:camouflage, Task:font, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:camouflage, Task:font, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:camouflage, Task:font, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:camouflage, Task:char, MASK:'random'
# 0.021016666666666666
# 0.2764333333333333
# 0.43695
# 0.03918333333333333
# 0.6957333333333334
# 0.72555
# Dset:camouflage, Task:char, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:camouflage, Task:char, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:camouflage, Task:char, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:font, MASK:'random'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:font, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:font, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:font, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:char, MASK:'random'
# 0.333
# 0.4086666666666667
# nan
# nan
# nan
# nan
# Dset:tiny, Task:char, MASK:'stratified_font'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:char, MASK:'stratified_char'
# nan
# nan
# nan
# nan
# nan
# nan
# Dset:tiny, Task:char, MASK:'compositional_char_font'
# nan
# nan
# nan
# nan
# nan
# nan

# %% [markdown]
# ## Show times

# %%
df = rm.get_score_df()

datasets = ["plain", "default_n=1000000_", "default_n=100000_", "mnist", "svhn", "tiny"]
datasets = ["tiny"]
models = ["mlp", "conv4", "resnet18", "resnet50", "vgg16", "warn"]


for dataset in datasets:
#     df_model = df[df["backbone.name"].str.contains(model)]
    print(dataset)
    if dataset in ["mnist", "svhn"]:
        df_dataset = df[df["dataset.name"].str.contains(dataset)]
    else:
        df_dataset = df[df["dataset.path"].str.contains(dataset)]
    for model in models:
        df_model = df_dataset[df_dataset["backbone.name"].str.contains(model)]
        print(df_model["val_batch_time"].mean())
# Out:
# tiny
# 0.0018573602040608723
# 0.0030656655629475913
# nan
# nan
# nan
# nan
